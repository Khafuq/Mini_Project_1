# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Expanded_data_with_more_features.csv")

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df['new_ParentEduc'] = df['ParentEduc'].apply(lambda x: 0 if pd.notnull(x) else 1)

# %%
df2 = df.dropna(subset=['ParentEduc'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28796 entries, 0 to 30640
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           28796 non-null  int64
#  1   Gender               28796 non-null  object
#  2   EthnicGroup          27070 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            28796 non-null  object
#  5   TestPrep             27074 non-null  object
#  6   ParentMaritalStatus  27680 non-null  object
#  7   PracticeSport        28215 non-null  object
#  8   IsFirstChild         27952 non-null  object
#  9   NrSiblings           27319 non-null  float64
#  10  TransportMeans       25863 non-null  object
#  11  WklyStudyHours       27903 non-null  object
#  12  MathScore            28796 non-null  int64
#  13  ReadingScore         28796 non-null  int64
#  14  WritingScore         28796 non-null  int64
# ...

# %%
df2
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df3 = df[df['ParentEduc'].isna()]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1845 entries, 22 to 30628
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1845 non-null   int64
#  1   Gender               1845 non-null   object
#  2   EthnicGroup          1731 non-null   object
#  3   ParentEduc           0 non-null      object
#  4   LunchType            1845 non-null   object
#  5   TestPrep             1737 non-null   object
#  6   ParentMaritalStatus  1771 non-null   object
#  7   PracticeSport        1795 non-null   object
#  8   IsFirstChild         1785 non-null   object
#  9   NrSiblings           1750 non-null   float64
#  10  TransportMeans       1644 non-null   object
#  11  WklyStudyHours       1783 non-null   object
#  12  MathScore            1845 non-null   int64
#  13  ReadingScore         1845 non-null   int64
#  14  WritingScore         1845 non-null   int64
# ...

# %%
df3
# Out:
#        Unnamed: 0  Gender EthnicGroup ParentEduc     LunchType   TestPrep  \
# 22             22    male     group D        NaN      standard       none
# 24             24    male     group D        NaN  free/reduced  completed
# 54             58    male     group D        NaN      standard  completed
# 70             77    male     group A        NaN      standard  completed
# 98            107    male     group E        NaN      standard  completed
# ...           ...     ...         ...        ...           ...        ...
# 30593          48  female     group C        NaN      standard       none
# 30598         107    male     group E        NaN      standard  completed
# 30610         366  female     group B        NaN      standard  completed
# 30623         641  female     group B        NaN      standard  completed
# 30628         744  female     group B        NaN  free/reduced       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# new_ParentEduc            0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# Gender                  object
# EthnicGroup             object
# ParentEduc              object
# LunchType               object
# TestPrep                object
# ParentMaritalStatus     object
# PracticeSport           object
# IsFirstChild            object
# NrSiblings             float64
# TransportMeans          object
# WklyStudyHours          object
# MathScore                int64
# ReadingScore             int64
# WritingScore             int64
# new_ParentEduc           int64
# dtype: object

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df['TestPrep'].unique()
# Out:
# array(['none', nan, 'completed'], dtype=object)

# %%
df['TestPrep'].value_counts()
# Out:
# none         18856
# completed     9955
# Name: TestPrep, dtype: int64

# %%
df['TestPrep'].mode()[0]
# Out:
# 'none'

# %%
df['TestPrep']=df['TestPrep'].fillna(df['TestPrep'].mode()[0])
df['TestPrep'].isnull().sum()
# Out:
# 0

# %%
df['IsFirstChild']=df['IsFirstChild'].fillna(df['IsFirstChild'].mode()[0])
df['IsFirstChild'].isnull().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep                  0
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild              0
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# new_ParentEduc            0
# dtype: int64

# %%
df.describe()
# Out:
#          NrSiblings     MathScore  ReadingScore  WritingScore  new_ParentEduc
# count  29069.000000  30641.000000  30641.000000  30641.000000    30641.000000
# mean       2.145894     66.558402     69.377533     68.418622        0.060213
# std        1.458242     15.361616     14.758952     15.443525        0.237886
# min        0.000000      0.000000     10.000000      4.000000        0.000000
# 25%        1.000000     56.000000     59.000000     58.000000        0.000000
# 50%        2.000000     67.000000     70.000000     69.000000        0.000000
# 75%        3.000000     78.000000     80.000000     79.000000        0.000000
# max        7.000000    100.000000    100.000000    100.000000        1.000000

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore', 'new_ParentEduc'],
#       dtype='object')

# %%
df.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard     none
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore  new_ParentEduc
# ...

# %%
df['Gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
k= sns.countplot(df,x="Gender")
k.bar_label(k.containers[0])
plt.title("Gender Distribution")
plt.show()

# %%
df['ParentEduc'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school', nan],
#       dtype=object)

# %%
df['ParentEduc']=df['ParentEduc'].fillna(df['ParentEduc'].mode()[0])
df['ParentEduc'].isnull().sum()
# Out:
# 0

# %%
df['ParentEduc'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df['ParentEduc']=df['ParentEduc'].replace('some high school','high school')

# %%
df['ParentEduc']=df['ParentEduc'].replace('some college',"bachelor's degree")

# %%
x1= df.groupby("Gender").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(x1)
# Out:
#         MathScore  ReadingScore  WritingScore
# Gender
# female  64.080654     72.853216     72.856457
# male    69.069856     65.854571     63.920418

# %%
sns.heatmap(x1,annot= True)
plt.title("Relationship between Gender and student's score")
plt.show()

# %%
gx= df.groupby("ParentEduc").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(gx)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   67.593476     70.294842     69.847859
# high school         63.523920     66.375312     64.540343
# master's degree     72.336134     75.832921     76.356896

# %%
sns.heatmap(gx,annot= True)
plt.title("Relationship between parent's Education and student's score")
plt.show()

# %%
sx=df.groupby("ParentMaritalStatus").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(sx)
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
sns.heatmap(sx,annot= True)
plt.title("Relationship between Parent Marital Status and student's score")
plt.show()

# %%
ve=df.groupby("WklyStudyHours").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(ve)
# Out:
#                 MathScore  ReadingScore  WritingScore
# WklyStudyHours
# 5 - 10          66.870491     69.660532     68.636280
# < 5             64.580359     68.176135     67.090192
# > 10            68.696655     70.365436     69.777778

# %%
sns.heatmap(ve,annot=True)
plt.title("Wkly Study Hours")
plt.show()

# %%
sns.boxplot(df, x="MathScore")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df, x="ReadingScore")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df, x="WritingScore")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
zc=df.groupby("TestPrep").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(zc)
# Out:
#            MathScore  ReadingScore  WritingScore
# TestPrep
# completed  69.546660     73.732998     74.703265
# none       65.120323     67.281495     65.394180

# %%
sns.heatmap(zc,annot=True)
plt.title("test preparation course")
plt.show()

# %%
gb=df.groupby("LunchType").agg({"MathScore":'mean',"ReadingScore":'mean',"WritingScore":'mean'})
print(gb)
# Out:
#               MathScore  ReadingScore  WritingScore
# LunchType
# free/reduced  58.862332     64.189735     62.650522
# standard      70.709370     72.175634     71.529716

# %%
gb= sns.countplot(df,x="LunchType")
gb.bar_label(gb.containers[0])
plt.title("Relationship between Lunch Type and Students Scores")
plt.show()

# %%
df.drop('NrSiblings', axis=1, inplace=True)

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1f',square=True,linewidths=.5,cbar_kws={"shrink":.5});
plt.title(" correlation of Maths,Reading and Writing Scores")
# Out:
# <ipython-input-57-180d741cb020>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt='.1f',square=True,linewidths=.5,cbar_kws={"shrink":.5});
# Text(0.5, 1.0, ' correlation of Maths,Reading and Writing Scores')
